# %%
# Homework 6

# %%
import numpy as np

# %%
# 3.1
list = [20, 27, 9, 12, 31, 17, 4, 50, 39, 35]

# %%
arr = np.array(list)

# %%
print(arr * 4)
# Out:
# [ 80 108  36  48 124  68  16 200 156 140]

# %%
print(np.mean(arr))
# Out:
# 24.4

# %%
print(np.median(arr))
# Out:
# 23.5

# %%
print(np.std(arr))
# Out:
# 13.828955130450023

# %%
print(np.argmin(arr))
print(np.argmax(arr))
# Out:
# 6
# 7

# %%
print(arr[6])
print(arr[7])
# Out:
# 4
# 50

# %%
print(np.min(arr))
print(np.max(arr))
# Out:
# 4
# 50

# %%
new_array = arr[arr > 20]
print(new_array)
# Out:
# [27 31 50 39 35]

# %%
# 3.2
matrix = [
    [5, 12, 17, 9],
    [8, 21, 14, 3],
    [6, 13, 19, 11]
]
arr2 = np.array(matrix)

# %%
arr2.shape
# 3 rows, 4 columns
# Out:
# (3, 4)

# %%
print(arr2[:, 2])
# Out:
# [17 14 19]

# %%
print(arr2[1, :])
# Out:
# [ 8 21 14  3]

# %%
print(arr2 * 2)
# Out:
# [[10 24 34 18]
#  [16 42 28  6]
#  [12 26 38 22]]

# %%
print(np.mean(arr2, axis=0))
# Out:
# [ 6.33333333 15.33333333 16.66666667  7.66666667]

# %%
print(np.mean(arr2))
# Out:
# 11.5

# %%
print(np.max(arr2, axis=1))
print(np.min(arr2, axis=0))
# Out:
# [17 21 19]
# [ 5 12 14  3]

# %%
arr2 = arr2.flatten()
# the array is now one dimensional (no columns)

# %%
print(np.argmin(arr2))
print(np.argmax(arr2))
# Out:
# 7
# 5

# %%
new_arr2 = arr[arr > 15]
new_arr2
# Out:
# array([20, 27, 31, 17, 50, 39, 35])

# %%
np.sort(new_arr2)
# Out:
# array([17, 20, 27, 31, 35, 39, 50])

# %%
# --- 4 ---

# %%
arr = np.array([
    [2, 3, 5],
    [14, 6, 8], 
    [11, 13, 17],
    [7, 10, 13]
])

def is_prime(num):

def prime_rows(my_array):
    for i in my_array:
        for k in i:
            if k
    return
