# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import skyfield
from skyfield.api import Star, load, wgs84
from skyfield.data import hipparcos
from skyfield.timelib import Time

# %%
def get_limiting_magnitude(target_lat, target_lon, csv_path='GaN2024.csv'):
    df = pd.read_csv(csv_path) 
    df = df.dropna(subset=['SQMReading', 'Latitude', 'Longitude'])
    df = df[df['SQMReading'] > 15]
    df = df[df['SQMReading'] < 23]
    df['distance'] = np.sqrt(
        (df['Latitude'] - target_lat)**2 + 
        (df['Longitude'] - target_lon)**2
    )
    nearest_row = df.loc[df['distance'].idxmin()]
    print(f"Nearest data point is {nearest_row['distance']:.2f} degrees away.")
    print(f"Local Sky Brightness (SQM): {nearest_row['SQMReading']}")
    nelm = ((nearest_row['SQMReading'] - 8.89) / 2) + 0.5
    print(f"NELM: {nelm}")
    return nelm

def find_visible_stars(lat, lon, limiting_mag, time_input):
    with load.open(hipparcos.URL) as f:
        df_stars = hipparcos.load_dataframe(f)
    bright_stars = df_stars[df_stars['magnitude'] <= limiting_mag]
    ts = load.timescale()
    t = ts.utc(time_input)
    planets = load('de421.bsp')
    earth = planets['earth']
    observer = earth + wgs84.latlon(latitude_degrees=lat, longitude_degrees=lon)
    stars = Star.from_dataframe(bright_stars)
    astrometric = observer.at(t).observe(stars)
    alt, az, distance = astrometric.apparent().altaz()
    visible_mask = alt.degrees > 0
    visible_stars = bright_stars[visible_mask]
    return visible_stars[['magnitude', 'ra_degrees', 'dec_degrees']]

# %%
latitude = 34.0967
longitude = -117.7198
time = (2000, 1, 1, 1, 0, 0)
nelm = get_limiting_magnitude(latitude, longitude,'GaN2024.csv')
visible_stars = find_visible_stars(latitude, longitude, nelm, time)

theta = np.deg2rad(visible_stars_local['azimuth_degrees'])
r = 90 - visible_stars_local['altitude_degrees']


plt.style.use("dark_background")
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': 'polar'})

ax.scatter(theta, r, 30 - (visible_stars_local['magnitude']) * 7.6, color='y', alpha=0.8)

ax.set_ylim(0, 90)
ax.set_theta_zero_location("N")
ax.set_theta_direction(-1)
r_ticks = [0, 30, 60, 90]

alt_labels = ['Zenith', '$60^{\circ}$', '$30^{\circ}$', '$0^{\circ}$ (Horizon)']
ax.set_yticks(r_ticks) 
ax.set_yticklabels(alt_labels, color = 'white')

az_labels = ['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW']
az_ticks = np.deg2rad(np.arange(0, 360, 45))
ax.set_xticks(az_ticks)
ax.set_xticklabels(az_labels, color='white')

ax.set_title('Local Night Sky View (Azimuth/Altitude Plot)', color='white', pad=15)
ax.grid(True, alpha=0.5)

plt.show()
# Out:
# Nearest data point is 0.54 degrees away.
# Local Sky Brightness (SQM): 15.59
# NELM: 3.8499999999999996
# ---------------------------------------------------------------------------
# EphemerisRangeError                       Traceback (most recent call last)
# Cell In[54], line 5
#       3 time = (2000, 1, 1, 1, 0, 0)
#       4 nelm = get_limiting_magnitude(latitude, longitude,'GaN2024.csv')
# ----> 5 visible_stars = find_visible_stars(latitude, longitude, nelm, time)
#       7 theta = np.deg2rad(visible_stars_local['azimuth_degrees'])
#       8 r = 90 - visible_stars_local['altitude_degrees']
#
# Cell In[52], line 27, in find_visible_stars(lat, lon, limiting_mag, time_input)
#      25 observer = earth + wgs84.latlon(latitude_degrees=lat, longitude_degrees=lon)
#      26 stars = Star.from_dataframe(bright_stars)
# ---> 27 astrometric = observer.at(t).observe(stars)
#      28 alt, az, distance = astrometric.apparent().altaz()
#      29 visible_mask = alt.degrees > 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/vectorlib.py:90, in VectorFunction.at(self, t)
#      86 if not isinstance(t, Time):
#      87     raise ValueError('please provide the at() method with a Time'
#      88                      ' instance as its argument, instead of the'
#      89                      ' value {0!r}'.format(t))
# ---> 90 p, v, gcrs_position, message = self._at(t)
#      91 center = self.center
#      92 position = build_position(p, v, t, center, self.target)
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/vectorlib.py:158, in VectorSum._at(self, t)
#     156 vfs = self.vector_functions
#     157 for vf in vfs:
# --> 158     p2, v2, _, message = vf._at(t)
#     159     if vf.center == 399:
#     160         gcrs_position = -p
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/jpllib.py:226, in ChebyshevPosition._at(self, t)
#     224     e = EphemerisRangeError(text, start_time, end_time, mask, segment)
#     225     e.__cause__ = None  # avoid exception chaining in Python 3
# --> 226     raise e
#     228 return position / AU_KM, velocity / AU_KM, None, None
#
# EphemerisRangeError: ephemeris segment only covers dates 1899-07-29 through 2053-10-09

# %%
latitude = 34.0967
longitude = -117.7198
nelm = get_limiting_magnitude(latitude, longitude,'GaN2024.csv')
visible_stars = find_visible_stars(latitude, longitude, nelm, (2023, 1, 18, 1, 0, 0))

fig, ax = plt.subplots()
plt.style.use("dark_background")
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Courier New']
ax.scatter(visible_stars['ra_degrees'], visible_stars['dec_degrees'], 8 - (visible_stars['magnitude']) * 2, 'y')
ax.set_xlim(visible_stars['ra_degrees'].min(), visible_stars['ra_degrees'].max())
ax.set_ylim(visible_stars['dec_degrees'].min(), visible_stars['dec_degrees'].max())
ax.grid(True)
ax.set(title='The Night Sky',
       xlabel='Right ascension (h)', ylabel='Declination (°)')
# Out:
# Nearest data point is 0.54 degrees away.
# Local Sky Brightness (SQM): 15.59
# NELM: 3.8499999999999996
# ---------------------------------------------------------------------------
# EphemerisRangeError                       Traceback (most recent call last)
# Cell In[43], line 4
#       2 longitude = -117.7198
#       3 nelm = get_limiting_magnitude(latitude, longitude,'GaN2024.csv')
# ----> 4 visible_stars = find_visible_stars(latitude, longitude, nelm, (2023, 1, 18, 1, 0, 0))
#       6 fig, ax = plt.subplots()
#       7 plt.style.use("dark_background")
#
# Cell In[40], line 27, in find_visible_stars(lat, lon, limiting_mag, time)
#      25 observer = earth + wgs84.latlon(latitude_degrees=lat, longitude_degrees=lon)
#      26 stars = Star.from_dataframe(bright_stars)
# ---> 27 astrometric = observer.at(t).observe(stars)
#      28 alt, az, distance = astrometric.apparent().altaz()
#      29 visible_mask = alt.degrees > 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/vectorlib.py:90, in VectorFunction.at(self, t)
#      86 if not isinstance(t, Time):
#      87     raise ValueError('please provide the at() method with a Time'
#      88                      ' instance as its argument, instead of the'
#      89                      ' value {0!r}'.format(t))
# ---> 90 p, v, gcrs_position, message = self._at(t)
#      91 center = self.center
#      92 position = build_position(p, v, t, center, self.target)
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/vectorlib.py:158, in VectorSum._at(self, t)
#     156 vfs = self.vector_functions
#     157 for vf in vfs:
# --> 158     p2, v2, _, message = vf._at(t)
#     159     if vf.center == 399:
#     160         gcrs_position = -p
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/jpllib.py:226, in ChebyshevPosition._at(self, t)
#     224     e = EphemerisRangeError(text, start_time, end_time, mask, segment)
#     225     e.__cause__ = None  # avoid exception chaining in Python 3
# --> 226     raise e
#     228 return position / AU_KM, velocity / AU_KM, None, None
#
# EphemerisRangeError: ephemeris segment only covers dates 1899-07-29 through 2053-10-09

# %%
# convert ra, dec to polar coordinates
theta = np.deg2rad(visible_stars['ra_degrees'])
radius = 90 - visible_stars['dec_degrees'] # radius is 0 at declination = 90

fig, ax = plt.subplots(figsize = (10, 10), subplot_kw = {'projection': 'polar'})
plt.scatter(theta, radius,  8 - (visible_stars['magnitude']) * 2)

ax.set_ylim(0, 120) 
ax.set_theta_zero_location("N") # RA=0 at the top
ax.set_theta_direction(-1) # RA increases clockwise

r_ticks = [0, 30, 60, 90, 120]
dec_labels = ['$90^{\circ}$', '$60^{\circ}$', '$30^{\circ}$', '$0^{\circ}$', '$-30^{\circ}$']
ax.set_yticks(r_ticks) 
ax.set_yticklabels(dec_labels)

print(f'This graph is the same as the rectangular one just plotted on a polar axis. The blank space represents the stars below the horizon. In oder to only show the stars one would see from earth, we need to use the altitude, azimuth system instead of RA, declination.')
# Out:
# This graph is the same as the rectangular one just plotted on a polar axis. The blank space represents the stars below the horizon. In oder to only show the stars one would see from earth, we need to use the altitude, azimuth system instead of RA, declination.

# %%
# Converting from RA, Dec to alt, az
df = pd.read_csv("GaN2024.csv")
eph = load("de421.bsp")
earth = eph['earth']
observer = wgs84.latlon(latitude_degrees = 40.7128, longitude_degrees = -74.0060, elevation_m=0)
ts = load.timescale()
t = ts.now()

if 'epoch_year' not in df.columns:
    df['epoch_year'] = 2024.0

stars = Star.from_dataframe(df)

astrometric = (earth + observer).at(t).observe(stars)
apparent = astrometric.apparent()
alt, az, distance = apparent.altaz()

# Add alt, az to the old data frame
df['altitude_degrees'] = alt.degrees
df['azimuth_degrees'] = az.degrees
visible_stars_local = df[df['altitude_degrees'] >= 0].copy()
print(f"Number of stars visible above the horizon: {len(visible_stars_local)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ra_hours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 12
#       9 if 'epoch_year' not in df.columns:
#      10     df['epoch_year'] = 2024.0
# ---> 12 stars = Star.from_dataframe(df)
#      14 astrometric = (earth + observer).at(t).observe(stars)
#      15 apparent = astrometric.apparent()
#
# File /opt/anaconda3/lib/python3.13/site-packages/skyfield/starlib.py:101, in Star.from_dataframe(cls, df)
#      97 @classmethod
#      98 def from_dataframe(cls, df):
#      99     epoch = 1721045.0 + _unwrap(df['epoch_year']) * 365.25
#     100     return cls(
# --> 101         ra_hours=_unwrap(df['ra_hours']),
#     102         dec_degrees=_unwrap(df['dec_degrees']),
#     103         ra_mas_per_year=_unwrap(df.get('ra_mas_per_year', 0)),
#     104         dec_mas_per_year=_unwrap(df.get('dec_mas_per_year', 0)),
#     105         parallax_mas=_unwrap(df.get('parallax_mas', 0)),
#     106         epoch=epoch,
#     107     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ra_hours'

# %%
theta = np.deg2rad(visible_stars_local['azimuth_degrees'])
r = 90 - visible_stars_local['altitude_degrees']


plt.style.use("dark_background")
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': 'polar'})

ax.scatter(theta, r, 30 - (visible_stars_local['magnitude']) * 7.6, color='y', alpha=0.8)

ax.set_ylim(0, 90)
ax.set_theta_zero_location("N")
ax.set_theta_direction(-1)
r_ticks = [0, 30, 60, 90]

alt_labels = ['Zenith', '$60^{\circ}$', '$30^{\circ}$', '$0^{\circ}$ (Horizon)']
ax.set_yticks(r_ticks) 
ax.set_yticklabels(alt_labels, color = 'white')

az_labels = ['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW']
az_ticks = np.deg2rad(np.arange(0, 360, 45))
ax.set_xticks(az_ticks)
ax.set_xticklabels(az_labels, color='white')

ax.set_title('Local Night Sky View (Azimuth/Altitude Plot)', color='white', pad=15)
ax.grid(True, alpha=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 theta = np.deg2rad(visible_stars_local['azimuth_degrees'])
#       2 r = 90 - visible_stars_local['altitude_degrees']
#       5 plt.style.use("dark_background")
#
# NameError: name 'visible_stars_local' is not defined
