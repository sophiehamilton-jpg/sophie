# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("exoplanet_data.csv", comment = "#")

# %%
df.shape
# The shape of the dataset is (570, 92); 570 rows and 92 columns
# Out:
# (570, 92)

# %%
df.columns
# soltype, pl_bmasselim, st_loggerr1, pl_eqt, sy_gaiamagerr1
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %%
df.value_counts()
# Out:
# pl_name      hostname   default_flag  sy_snum  sy_pnum  discoverymethod  disc_year  disc_facility                                 soltype              pl_controv_flag  pl_refname                                                                                                                                pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  pl_orbsmaxlim  pl_rade    pl_radeerr1  pl_radeerr2  pl_radelim  pl_radj   pl_radjerr1  pl_radjerr2  pl_radjlim  pl_bmasse  pl_bmasseerr1  pl_bmasseerr2  pl_bmasselim  pl_bmassj  pl_bmassjerr1  pl_bmassjerr2  pl_bmassjlim  pl_bmassprov  pl_orbeccen  pl_orbeccenerr1  pl_orbeccenerr2  pl_orbeccenlim  pl_insol  pl_insolerr1  pl_insolerr2  pl_insollim  pl_eqt  pl_eqterr1  pl_eqterr2  pl_eqtlim  ttv_flag  st_refname                                                                                                                                st_spectype       st_teff  st_tefferr1  st_tefferr2 
# ...
